# %%
# !nvidia-smi
# Out:
# Wed Aug 26 19:02:30 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             15W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !unzip -q project_for_colab.zip -d /content/project
# %cd /content/project
# Out:
# unzip:  cannot find or open project_for_colab.zip, project_for_colab.zip.zip or project_for_colab.zip.ZIP.
# /content/project

# %%
# !ls
# Out:
# app.py	logs	 params.yaml  requirements.txt	setup.py  template.py
# config	main.py  README.md    research		src

# %%
# !pip install -q -r requirements.txt
# Out:
#   Preparing metadata (setup.py) ... done

# %%
# %%writefile README.md
# # Text Summarizer Project
# Out:
# Overwriting README.md

# %%
# !ls
# Out:
# app.py	logs	 params.yaml  requirements.txt	setup.py  template.py
# config	main.py  README.md    research		src

# %%
# !pip install -r requirements.txt
# Out:
# Obtaining file:///content/project (from -r requirements.txt (line 25))
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: textSummarizer
#     Found existing installation: textSummarizer 0.0.0
#     Uninstalling textSummarizer-0.0.0:
#       Successfully uninstalled textSummarizer-0.0.0
#   Running setup.py develop for textSummarizer
# ...

# %%
# %cd /content/project
# !ls
# Out:
# /content/project
# app.py	logs	 params.yaml  requirements.txt	setup.py  template.py
# config	main.py  README.md    research		src

# %%
# !pip show transformers accelerate torch | grep -E "Name|Version"
# Out:
# Name: transformers
# Version: 4.46.3
# Name: accelerate
# Version: 1.1.1
# Name: torch
# Version: 2.5.1

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !pip uninstall -y torchvision torchaudio
# Out:
# Found existing installation: torchvision 0.26.0+cu128
# Uninstalling torchvision-0.26.0+cu128:
#   Successfully uninstalled torchvision-0.26.0+cu128
# Found existing installation: torchaudio 2.11.0+cu128
# Uninstalling torchaudio-2.11.0+cu128:
#   Successfully uninstalled torchaudio-2.11.0+cu128

# %%
# %cd /content/project
# !pip show transformers torch torchvision 2>/dev/null | grep -E "Name|Version"
# Out:
# /content/project
# Name: transformers
# Version: 4.46.3
# Name: torch
# Version: 2.5.1

# %%
import os
os.environ["WANDB_DISABLED"] = "true"
# !python main.py
# Out:
# [2026-08-26 19:17:40,108: INFO: utils: NumExpr defaulting to 2 threads.]
# [2026-08-26 19:17:40,288: INFO: config: PyTorch version 2.5.1 available.]
# [2026-08-26 19:17:40,289: INFO: config: Polars version 1.35.2 available.]
# [2026-08-26 19:17:40,290: INFO: config: Duckdb version 1.3.2 available.]
# [2026-08-26 19:17:40,290: INFO: config: TensorFlow version 2.20.0 available.]
# [2026-08-26 19:17:40,291: INFO: config: JAX version 0.7.2 available.]
# 2026-08-26 19:17:41.265056: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [2026-08-26 19:17:48,446: INFO: main: >>>>>> stage Data Ingestion stage started <<<<<<]
# [2026-08-26 19:17:48,449: INFO: common: yaml file: config/config.yaml loaded successfully]
# ...

# %%
# !zip -qr artifacts_trained.zip artifacts

# %%
# !ls -lh artifacts_trained.zip
# Out:
# -rw-r--r-- 1 root root 8.0G Aug 26 20:15 artifacts_trained.zip

# %%
# !du -sh artifacts/*
# !du -sh artifacts/model_trainer/*
# Out:
# 53M	artifacts/data_ingestion
# 24M	artifacts/data_transformation
# 8.0K	artifacts/data_validation
# 8.0K	artifacts/model_evaluation
# 8.6G	artifacts/model_trainer
# 6.4G	artifacts/model_trainer/checkpoint-920
# 2.2G	artifacts/model_trainer/pegasus-samsum-model
# 52K	artifacts/model_trainer/runs
# 8.2M	artifacts/model_trainer/tokenizer

# %%
# !rm artifacts_trained.zip
# !zip -qr artifacts_trained.zip artifacts/model_trainer/pegasus-samsum-model artifacts/model_trainer/tokenizer

# %%
# !ls -lh artifacts_trained.zip
# Out:
# -rw-r--r-- 1 root root 2.0G Aug 26 20:30 artifacts_trained.zip
